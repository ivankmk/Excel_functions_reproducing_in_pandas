# %% [markdown]
# # <center> Implementation Excel functions using Pandas library. </center>
# ## <center> Chapter 2 : Number Filters</center>
# # <center> 🐼 + 🐍 = 📊<center>

# %% [markdown]
# ## Content:
# * [1. Number Filters -> Equals](#1. Number Filters -> Equals)
# * [2. Number Filters -> Does Not Equal](#2. Number Filters -> Does Not Equal)
# * [3. Number Filters -> Greater Than](#3. Number Filters -> Greater Than)
# * [4. Number Filters -> Greater Than or Equal To](#4. Number Filters -> Greater Than or Equal To)
# * [5. Number Filters -> Less Than](#5. Number Filters -> Less Than)
# * [6. Number Filters -> Less Than Or Equal To](#6. Number Filters -> Less Than Or Equal To)
# * [7. Number Filters -> Between](#7. Number Filters -> Between)
# * [8. Number Filters -> Top 10](#8. Number Filters -> Top 10)
# * [9. Number Filters -> Above Average](#9. Number Filters -> Above Average)
# * [10. Number Filters -> Below Average](#10. Number Filters -> Below Average)

# %% [markdown]
# # 1. Number Filters -> Equals <a class="anchor" id="1. Number Filters -> Equals"></a>
# ***
# <img style="float: right; width: 40%;" src="img/number_filter_equals.png">
#
# ## Select rows in the table based on values in a column.

# %% [markdown]
# ### 🔥Same in Pandas:
#
# First step - import our data with Pandas ```.read_csv()``` method:

# %%
import pandas as pd

# %%
dataset = pd.read_csv('Fleet_Data.csv')

# %%
total_cnt_filter = dataset['Total'] == 10
dataset[total_cnt_filter].head()
# Out:
#             Parent Airline                Airline   Aircraft Type  Current  \
# 13                Aeroflot        Aurora Airlines     Airbus A319     10.0
# 34                Aeroflot               Aeroflot  Ilyushin Il-96      NaN
# 50   Aerolineas Argentinas  Aerolineas Argentinas     Airbus A330      9.0
# 76              Air Arabia       Air Arabia Maroc     Airbus A320      5.0
# 159             Air Europa             Air Europa       ATR 42/72      4.0
#
#      Future  Historic  Total  Orders Unit Cost Total Cost (Current)  \
# 13      NaN       NaN   10.0     NaN       $90                 $896
# 34      NaN      10.0   10.0     NaN       $45                   $0
# 50      1.0       NaN   10.0     NaN      $240               $2,160
# 76      NaN       5.0   10.0     NaN       $98                 $490
# 159     NaN       6.0   10.0     NaN       $22                  $88
#
#      Average Age
# 13          11.0
# 34           NaN
# 50           9.3
# 76           4.4
# 159         21.9

# %% [markdown]
# ***
# # 2. Number Filters -> Does Not Equal <a class="anchor" id="2. Number Filters -> Does Not Equal"></a>
# ***
# <img style="float: right; width: 40%;" src="img/number_filter_noteual.png">
#
# ## Select all rows in the table except one or more values.

# %% [markdown]
# ### 🔥Same in Pandas:

# %%
dataset.head(3)
# Out:
#     Parent Airline          Airline Aircraft Type  Current  Future  Historic  \
# 0  Aegean Airlines  Aegean Airlines   Airbus A319      1.0     NaN       3.0
# 1  Aegean Airlines      Olympic Air   Airbus A319      NaN     NaN       8.0
# 2  Aegean Airlines  Aegean Airlines   Airbus A320     38.0     NaN       3.0
#
#    Total  Orders Unit Cost Total Cost (Current)  Average Age
# 0    4.0     NaN       $90                  $90         11.6
# 1    8.0     NaN       $90                   $0          NaN
# 2   41.0     NaN       $98               $3,724          7.5

# %%
not_equal_filter = ~dataset['Total'].isin([10, 4, 8])
dataset[not_equal_filter].head()
# Out:
#     Parent Airline          Airline Aircraft Type  Current  Future  Historic  \
# 2  Aegean Airlines  Aegean Airlines   Airbus A320     38.0     NaN       3.0
# 3  Aegean Airlines      Olympic Air   Airbus A320      NaN     NaN       9.0
# 5  Aegean Airlines      Olympic Air     ATR 42/72      2.0     NaN       NaN
# 6  Aegean Airlines  Aegean Airlines     ATR 42/72      NaN     NaN       6.0
# 7  Aegean Airlines  Aegean Airlines    Boeing 737      NaN     NaN      17.0
#
#    Total  Orders Unit Cost Total Cost (Current)  Average Age
# 2   41.0     NaN       $98               $3,724          7.5
# 3    9.0     NaN       $98                   $0          NaN
# 5    2.0     NaN       $22                  $44          2.4
# 6    6.0     NaN       $22                   $0          NaN
# 7   17.0     NaN       $74                   $0          NaN

# %% [markdown]
# The below example if we need to make a more sophisticated filter - for instance using different columns.
# As example, remove all rows who have a number of ```Aircrafts``` = 10 and 41, and also ```Airline``` with name ```Olympic Air``` and ```Aegean Airlines```

# %%
ten_aircrafts = ~dataset['Total'].isin([10, 41])
not_olympic_air = ~dataset['Airline'].isin(['Olympic Air', 'Aegean Airlines'])

dataset[ten_aircrafts & not_olympic_air].head()
# Out:
#    Parent Airline           Airline Aircraft Type  Current  Future  Historic  \
# 10       Aeroflot          Aeroflot   Airbus A310      NaN     NaN      14.0
# 11       Aeroflot  Rossiya Airlines   Airbus A319     26.0     NaN       5.0
# 12       Aeroflot          Aeroflot   Airbus A319      NaN     NaN      15.0
# 14       Aeroflot          Aeroflot   Airbus A320     71.0     1.0       3.0
# 15       Aeroflot  Rossiya Airlines   Airbus A320      5.0     NaN       8.0
#
#     Total  Orders Unit Cost Total Cost (Current)  Average Age
# 10   14.0     NaN       $75                   $0          NaN
# 11   31.0     NaN       $90               $2,330         12.7
# 12   15.0     NaN       $90                   $0          NaN
# 14   75.0    11.0       $98               $6,958          5.7
# 15   13.0     NaN       $98                 $490         15.2

# %% [markdown]
# ***
# # 3. Number Filters -> Greater Than <a class="anchor" id="3. Number Filters -> Greater Than">
# ***
# <img style="float: right; width: 40%;" src="img/number_filter_greater.png">
#
# ## Select all rows greater than certain value.

# %% [markdown]
# ### 🔥Same in Pandas:

# %%
more_400_aircrafts = dataset['Total'] > 400

dataset[more_400_aircrafts]
# Out:
#           Parent Airline             Airline Aircraft Type  Current  Future  \
# 1267             Ryanair             RyanAir    Boeing 737    366.0    10.0
# 1362  Southwest Airlines  Southwest Airlines    Boeing 737    718.0    38.0
# 1503     United Airlines     United Airlines    Boeing 737    321.0     2.0
#
#       Historic  Total  Orders Unit Cost Total Cost (Current)  Average Age
# 1267     100.0  476.0   205.0       $74              $27,077          6.6
# 1362     195.0  952.0   284.0       $74              $53,118         11.7
# 1503     295.0  620.0   103.0       $74              $23,748         10.1

# %% [markdown]
# ***
# # 4. Number Filters -> Greater Than or Equal To <a class="anchor" id="4. Number Filters -> Greater Than or Equal To">
# ***
# <img style="float: right; width: 40%;" src="img/number_filter_greaterorequal.png">
#
# ## Select all rows greater or equal than certain value.

# %% [markdown]
# ### 🔥Same in Pandas:

# %%
more_111_aircrafts = dataset['Total'] >= 111

dataset[more_111_aircrafts].head()
# Out:
#             Parent Airline                  Airline Aircraft Type  Current  \
# 52   Aerolineas Argentinas    Aerolineas Argentinas    Boeing 737     40.0
# 87              Air Berlin               Air Berlin   Airbus A320     54.0
# 91              Air Berlin               Air Berlin    Boeing 737     14.0
# 135              Air China                Air China    Boeing 737    144.0
# 137              Air China  Shandong Airlines (51%)    Boeing 737     98.0
#
#      Future  Historic  Total  Orders Unit Cost Total Cost (Current)  \
# 52      1.0      77.0  118.0     NaN       $74               $2,959
# 87      7.0      50.0  111.0     NaN       $98               $5,292
# 91      NaN     141.0  155.0     NaN       $74               $1,036
# 135     1.0      75.0  220.0    70.0       $74              $10,653
# 137     1.0      16.0  115.0    36.0       $74               $7,250
#
#      Average Age
# 52           6.6
# 87           7.6
# 91           9.5
# 135          6.6
# 137          4.7

# %% [markdown]
# ***
# # 5. Number Filters -> Less Than <a class="anchor" id="5. Number Filters -> Less Than">
# ***
# <img style="float: right; width: 40%;" src="img/number_filter_less.png">
#
# ## Select all rows less than certain value.

# %% [markdown]
# ### 🔥Same in Pandas:

# %%
less_two_aircrafts = dataset['Total'] < 2

dataset[less_two_aircrafts].head()
# Out:
#            Parent Airline                Airline    Aircraft Type  Current  \
# 33               Aeroflot       Rossiya Airlines   Ilyushin Il-62      NaN
# 41               Aeroflot               Aeroflot   Tupolev Tu-134      NaN
# 42               Aeroflot       Rossiya Airlines   Tupolev Tu-154      NaN
# 47               Aeroflot               Aeroflot  Yakovlev Yak-42      NaN
# 55  Aerolineas Argentinas  Aerolineas Argentinas       Boeing 757      NaN
#
#     Future  Historic  Total  Orders Unit Cost Total Cost (Current)  \
# 33     NaN       1.0    1.0     NaN       $45                   $0
# 41     NaN       1.0    1.0     NaN       $16                   $0
# 42     NaN       1.0    1.0     NaN       $16                   $0
# 47     NaN       1.0    1.0     NaN       NaN                   $0
# 55     NaN       1.0    1.0     NaN       $73                   $0
#
#     Average Age
# 33          NaN
# 41          NaN
# 42          NaN
# 47          NaN
# 55          NaN

# %% [markdown]
# ***
# # 6. Number Filters -> Less Than Or Equal To <a class="anchor" id="6. Number Filters -> Less Than Or Equal To">
# ***
# <img style="float: right; width: 40%;" src="img/number_filter_lessorequal.png">
#
# ## Select all rows less or equal than certain value.

# %% [markdown]
# ### 🔥Same in Pandas:

# %%
lessequal_three_aircrafts = dataset['Total'] <= 3

dataset[lessequal_three_aircrafts].head()
# Out:
#      Parent Airline           Airline   Aircraft Type  Current  Future  \
# 5   Aegean Airlines       Olympic Air       ATR 42/72      2.0     NaN
# 19         Aeroflot          Aeroflot  Antonov An-124      NaN     NaN
# 20         Aeroflot  Rossiya Airlines  Antonov An-124      NaN     NaN
# 28         Aeroflot  Rossiya Airlines      Boeing 767      NaN     NaN
# 33         Aeroflot  Rossiya Airlines  Ilyushin Il-62      NaN     NaN
#
#     Historic  Total  Orders Unit Cost Total Cost (Current)  Average Age
# 5        NaN    2.0     NaN       $22                  $44          2.4
# 19       3.0    3.0     NaN       $75                   $0          NaN
# 20       2.0    2.0     NaN       $75                   $0          NaN
# 28       3.0    3.0     NaN      $187                   $0          NaN
# 33       1.0    1.0     NaN       $45                   $0          NaN

# %% [markdown]
# ***
# # 7. Number Filters -> Between <a class="anchor" id="7. Number Filters -> Between">
# ***
# <img style="float: right; width: 40%;" src="img/number_filter_between.png">
#
# ## Select all rows between than certain values.

# %% [markdown]
# ### 🔥Same in Pandas:

# %% [markdown]
# ```Series.between(left, right, inclusive=True)```

# %%
between_aircrafts = dataset['Total'].between(140, 150, inclusive=True)

dataset[between_aircrafts]
# Out:
#                Parent Airline                  Airline  \
# 526   China Southern Airlines  China Southern Airlines
# 561            Delta Airlines             Endeavor Air
# 714          Garuda Indonesia         Garuda Indonesia
# 857                    IndiGo                   IndiGo
# 902                   JetBlue          JetBlue Airways
# 1490         Turkish Airlines         Turkish Airlines
#
#                 Aircraft Type  Current  Future  Historic  Total  Orders  \
# 526               Airbus A320    123.0     8.0      14.0  145.0    25.0
# 561   Canadair CRJ-100 Series     53.0     NaN      87.0  140.0     NaN
# 714                Boeing 737     74.0     NaN      75.0  149.0    50.0
# 857               Airbus A320    124.0    10.0      16.0  150.0   400.0
# 902               Airbus A320    130.0     NaN      12.0  142.0    25.0
# 1490               Boeing 737     92.0     NaN      50.0  142.0    75.0
#
#      Unit Cost Total Cost (Current)  Average Age
# 526        $98              $12,054          7.3
# 561        $32               $1,688         12.7
# 714        $74               $5,475          5.3
# 857        $98              $12,152          5.2
# 902        $98              $12,740         11.3
# 1490       $74               $6,806          6.4

# %% [markdown]
# ***
# # 8. Number Filters -> Top 10 <a class="anchor" id="8. Number Filters -> Top 10">
# ***
# <img style="float: right; width: 40%;" src="img/number_filter_top10.png">
#
# ## Select Top 10 rows.

# %% [markdown]
# ### 🔥Same in Pandas:

# %%
dataset.sort_values('Current', ascending=False).head(10)
# Out:
#                Parent Airline                  Airline  \
# 1362       Southwest Airlines       Southwest Airlines
# 1267                  Ryanair                  RyanAir
# 1503          United Airlines          United Airlines
# 366         American Airlines        American Airlines
# 667             FedEx Express       FedEx Feeder Fleet
# 361         American Airlines        American Airlines
# 531   China Southern Airlines  China Southern Airlines
# 1351         Skywest Airlines         Skywest Airlines
# 494    China Eastern Airlines   China Eastern Airlines
# 615                  Emirates                 Emirates
#
#                   Aircraft Type  Current  Future  Historic  Total  Orders  \
# 1362                 Boeing 737    718.0    38.0     195.0  952.0   284.0
# 1267                 Boeing 737    366.0    10.0     100.0  476.0   205.0
# 1503                 Boeing 737    321.0     2.0     295.0  620.0   103.0
# 366                  Boeing 737    282.0     4.0      46.0  332.0   121.0
# 667   Cessna 208B Grand Caravan    241.0     NaN       NaN    NaN     NaN
# 361                 Airbus A321    197.0    12.0       NaN  209.0   122.0
# 531                  Boeing 737    169.0     NaN      65.0  234.0     1.0
# 1351    Canadair CRJ-100 Series    166.0     NaN      33.0  199.0     NaN
# 494                 Airbus A320    165.0     2.0      24.0  191.0   130.0
# 615                  Boeing 777    159.0     5.0      10.0  174.0   177.0
#
#      Unit Cost Total Cost (Current)  Average Age
# 1362       $74              $53,118         11.7
# 1267       $74              $27,077          6.6
# 1503       $74              $23,748         10.1
# 366        $74              $20,862          7.7
# 667         $3                 $610          NaN
# 361       $115              $22,635          4.9
# 531        $74              $12,503          6.8
# 1351       $32               $5,287         14.5
# 494        $98              $16,170          6.8
# 615       $295              $46,833          6.4

# %% [markdown]
# ***
# # 9. Number Filters -> Above Average <a class="anchor" id="9. Number Filters -> Above Average">
# ***
# <img style="float: right; width: 40%;" src="img/number_filter_aboveaverage.png">
#
# ## Select all rows bigger than average value.

# %% [markdown]
# ### 🔥Same in Pandas:

# %%
total_average = dataset['Total'].mean()

# %%
above_average = dataset['Total'] > total_average
dataset[above_average].head()
# Out:
#      Parent Airline           Airline Aircraft Type  Current  Future  \
# 2   Aegean Airlines   Aegean Airlines   Airbus A320     38.0     NaN
# 11         Aeroflot  Rossiya Airlines   Airbus A319     26.0     NaN
# 14         Aeroflot          Aeroflot   Airbus A320     71.0     1.0
# 16         Aeroflot          Aeroflot   Airbus A321     31.0     NaN
# 22         Aeroflot          Aeroflot    Boeing 737     20.0     1.0
#
#     Historic  Total  Orders Unit Cost Total Cost (Current)  Average Age
# 2        3.0   41.0     NaN       $98               $3,724          7.5
# 11       5.0   31.0     NaN       $90               $2,330         12.7
# 14       3.0   75.0    11.0       $98               $6,958          5.7
# 16       8.0   39.0     9.0      $115               $3,562          3.6
# 22      16.0   37.0    26.0       $74               $1,480          1.6

# %% [markdown]
# ***
# # 10. Number Filters -> Below Average <a class="anchor" id="10. Number Filters -> Below Average">
# ***
# <img style="float: right; width: 40%;" src="img/number_filter_belowaverage.png">
#
# ## Select all rows less than average value.

# %% [markdown]
# ### 🔥Same in Pandas:

# %%
total_average = dataset['Total'].mean()

# %%
below_average = dataset['Total'] < total_average
dataset[below_average].head()
# Out:
#     Parent Airline          Airline Aircraft Type  Current  Future  Historic  \
# 0  Aegean Airlines  Aegean Airlines   Airbus A319      1.0     NaN       3.0
# 1  Aegean Airlines      Olympic Air   Airbus A319      NaN     NaN       8.0
# 3  Aegean Airlines      Olympic Air   Airbus A320      NaN     NaN       9.0
# 4  Aegean Airlines  Aegean Airlines   Airbus A321      8.0     NaN       NaN
# 5  Aegean Airlines      Olympic Air     ATR 42/72      2.0     NaN       NaN
#
#    Total  Orders Unit Cost Total Cost (Current)  Average Age
# 0    4.0     NaN       $90                  $90         11.6
# 1    8.0     NaN       $90                   $0          NaN
# 3    9.0     NaN       $98                   $0          NaN
# 4    8.0     NaN      $115                 $919         10.3
# 5    2.0     NaN       $22                  $44          2.4
